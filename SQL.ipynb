# %% [markdown]
# <a href="https://colab.research.google.com/github/girishvnair/JupyterNotebooks/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
Path('my_data.db').touch()

# %%
import sqlite3
conn = sqlite3.connect('my_data.db')
c = conn.cursor()

# %%
import pandas as pd
# load the data into a Pandas DataFrame
mobile_price = pd.read_csv('mobile_price.csv')
# write the data to a sqlite table
mobile_price.to_sql('users', conn, if_exists='append', index = False)

# %%
c.execute('''select * from users limit 1''').fetchall()
# Out:
# [(842,
#   0,
#   2.2,
#   0,
#   1,
#   0,
#   7,
#   0.6,
#   188,
#   2,
#   2,
#   20,
#   756,
#   2549,
#   9,
#   7,
#   19,
#   0,
#   0,
#   1,
#   1)]

# %%
pd.read_sql('''SELECT * FROM users''',conn)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...
